# %%
import gather_memtier_statistics as gmts
import graph_xputresp_vs_multigets as xput_vs_multi
import graph_xput_vs_time as xput_vs_time
import graph_responsetime as resptime
import graph_queuelength as queuelen
import summary_table as summ
import matplotlib.pyplot as plt
import numpy as np
import os, sys

# %%
exp5_1_dir = "/home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912"
exp5_2_dir = "/home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308"

# %%
# Experiment 5: MultiGets
# Plot the throughput and response time measured in the middleware

experiment_label = "exp5"

middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log", "client_02_0.log", "client_02_1.log", "client_03_0.log", "client_03_1.log"]
dir_suffix_regex_string = "_\d*multiget"
warmup_period_endtime = 10
cooldown_period_starttime = 72
outdir = "./graphs"
num_threads = 6
ylim_xput = 18000
ylim_resp = 2.5
xlim = 10
shard = xput_vs_multi.gather_data(exp5_1_dir, experiment_label, "sharded", middlewares, client_logfiles, dir_suffix_regex_string, warmup_period_endtime, cooldown_period_starttime, outdir, num_threads, ylim_xput, ylim_resp, xlim)
nonshard = xput_vs_multi.gather_data(exp5_2_dir, experiment_label, "nonsharded", middlewares, client_logfiles, dir_suffix_regex_string, warmup_period_endtime, cooldown_period_starttime, outdir, num_threads, ylim_xput, ylim_resp, xlim)

shard = shard.sort_values('multigetSize')


nonshard = nonshard.sort_values('multigetSize')
# Out:
# Input directory is  /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912
# Setting is  sharded
# Saving all graphs to  ./graphs
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/middleware_04/2017-11-24 090230
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/middleware_05/2017-11-24 090231
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/middleware_04/2017-11-24 090937
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/middleware_05/2017-11-24 090938
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/middleware_04/2017-11-24 091645
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/middleware_05/2017-11-24 091645
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_3multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/middleware_04/2017-11-24 090417
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/middleware_05/2017-11-24 090417
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/middleware_04/2017-11-24 091124
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/middleware_05/2017-11-24 091125
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/middleware_04/2017-11-24 091831
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/middleware_05/2017-11-24 091832
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_6multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/middleware_04/2017-11-24 090041
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/middleware_05/2017-11-24 090042
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/middleware_04/2017-11-24 090751
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/middleware_05/2017-11-24 090751
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/middleware_04/2017-11-24 091458
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/middleware_05/2017-11-24 091458
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_1multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/middleware_04/2017-11-24 090604
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/middleware_05/2017-11-24 090604
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/middleware_04/2017-11-24 091311
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/middleware_05/2017-11-24 091311
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/middleware_04/2017-11-24 092018
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/middleware_05/2017-11-24 092019
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_1_multigets_sharded_2017-11-24_085912/sharded_9multiget/3/client_03_1.log
# Input directory is  /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308
# Setting is  nonsharded
# Saving all graphs to  ./graphs
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/middleware_04/2017-11-24 092554
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/middleware_05/2017-11-24 092554
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/middleware_04/2017-11-24 093300
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/middleware_05/2017-11-24 093301
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/middleware_04/2017-11-24 094008
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/middleware_05/2017-11-24 094008
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_3multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/middleware_04/2017-11-24 092407
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/middleware_05/2017-11-24 092408
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/middleware_04/2017-11-24 093114
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/middleware_05/2017-11-24 093114
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/middleware_04/2017-11-24 093821
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/middleware_05/2017-11-24 093821
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_1multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/middleware_04/2017-11-24 092741
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/middleware_05/2017-11-24 092741
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/middleware_04/2017-11-24 093447
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/middleware_05/2017-11-24 093448
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/middleware_04/2017-11-24 094155
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/middleware_05/2017-11-24 094155
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_6multiget/3/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/middleware_04/2017-11-24 092927
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/middleware_05/2017-11-24 092928
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/1/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/middleware_04/2017-11-24 093634
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/middleware_05/2017-11-24 093634
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/2/client_03_1.log
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/middleware_04/2017-11-24 094341
# Concatenating requestlogs in /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/middleware_05/2017-11-24 094342
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_01_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_01_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_02_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_02_1.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_03_0.log
# Extracting stats from client log /home/flo/Documents/eth-asl-final-experiment-data/exp5/5_2_multigets_nonsharded_2017-11-24_092308/nonsharded_9multiget/3/client_03_1.log

# %%
## Response Time

means_shard_resp = shard.loc['mean', 'responsetime']
means_shard_resp
std_shard_resp = shard.loc['std', 'responsetime']

means_nonshard_resp = nonshard.loc['mean', 'responsetime']
means_nonshard_resp
std_nonshard_resp = nonshard.loc['std', 'responsetime']

indices = np.arange(4)
width = 0.35 
fig, ax = plt.subplots()
shard_bar = ax.bar(indices, means_shard_resp, width, color='#e31a1c', yerr=std_shard_resp)
nonshard_bar = ax.bar(indices + width, means_nonshard_resp, width, color='#fed976', yerr=std_nonshard_resp)

ax.legend((shard_bar[0], nonshard_bar[0]), ('Sharded', 'Non-Sharded'), loc='upper left')
ax.set_xticks(indices + width / 2)
ax.set_xticklabels(('1', '3', '6', '9'))
ax.set_ylabel('Response Time (ms)')
ax.set_xlabel('Number of keys in GETs')
ax.set_title('Response Time (MT) vs. different MultiGET sizes')
ax.set_ylim([0,2.5])

plt.show()

# %%
## Throughput

means_shard_xput = shard.loc['mean', 'throughput']
means_shard_xput
std_shard_xput = shard.loc['std', 'throughput']

means_nonshard_xput = nonshard.loc['mean', 'throughput']
means_nonshard_xput
std_nonshard_xput = nonshard.loc['std', 'throughput']

indices = np.arange(4)
width = 0.35 
fig, ax = plt.subplots()
shard_bar = ax.bar(indices, means_shard_xput, width, color='#006d2c', yerr=std_shard_xput)
nonshard_bar = ax.bar(indices + width, means_nonshard_xput, width, color='#66c2a4', yerr=std_nonshard_xput)

ax.legend((shard_bar[0], nonshard_bar[0]), ('Sharded', 'Non-Sharded'), loc='upper right')
ax.set_xticks(indices + width / 2)
ax.set_xticklabels(('1', '3', '6', '9'))
ax.set_ylabel('Throughput (op/s)')
ax.set_xlabel('Number of keys in GETs')
ax.set_title('Throughput (MT) vs. different MultiGET sizes')
ax.set_ylim([0,11000])

plt.show()

# %%
### Summary Table: Finding maximum throughput configuration
# Maximum throughput for one middleware

inputdir = exp4_dir
workload = "writeOnly"
workers = [8, 16, 32, 64]
vc_configs = {8: [1, 4, 8],
              16: [1, 4, 8, 12, 16],
              32: [1, 4, 8, 12, 16, 20, 24],
              64: [1, 4, 8, 12, 16, 20, 24, 32]}
reps = 3
middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log", "client_02_0.log", "client_02_1.log", "client_03_0.log", "client_03_1.log"]
ping_logfiles = ["client_ping_01_0.log", "client_ping_01_1.log", "client_ping_02_0.log", "client_ping_02_1.log", "client_ping_03_0.log", "client_ping_03_1.log"]
warmup_period_endtime = 10
cooldown_period_starttime = 72
num_threads = 

for worker in workers:
    vc, xput = summ.find_max_throughput(inputdir, workload, worker, vc_configs[worker], reps, client_logfiles, warmup_period_endtime, cooldown_period_starttime)
    print(vc, xput)
    thinktime_ms = summ.average_pings_over_reps(inputdir, workload, worker, vc, reps, ping_logfiles)
    summ.
    extract_summary_from_config(inputdir, workload, worker, vc, reps, xput, thinktime_ms, num_threads, middlewares, warmup_period_endtime, cooldown_period_starttime)

# %%
## Drawing the response time break-down of a a few interesting configurations of readOnly workload
inputdir = exp4_dir
worker_configs = [8, 16, 32, 64] # Provide worker configurations used
vc_configs = [1, 4, 8, 12, 16, 20, 24, 32, 48, 64] # Provide vc configurations used
reps = [1, 2, 3]
middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log", "client_02_0.log", "client_02_1.log", "client_03_0.log", "client_03_1.log"]
warmup_period_endtime = 10
cooldown_period_starttime = 72
outdir = "./graphs"
experiment_label = "exp4"
xlim=12.5
num_threads=6

fig, axes = plt.subplots(1,4, sharey=True, figsize=(15, 4))
resptime.graph_responsetime(8, 8, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[0])
resptime.graph_responsetime(16, 8, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[1])

resptime.graph_responsetime(32, 8, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[2])
resptime.graph_responsetime(64, 8, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[3])
fig.tight_layout()
plt.show()

fig.savefig(os.path.join(outdir, experiment_label, "responseTimeBreakDown_writeOnly.png"), dpi=300)

# %%
## Drawing the response time break-down of a a few interesting configurations of writeOnly workload
inputdir = exp3_2_rerun
worker_configs = [8, 16, 32, 64] # Provide worker configurations used
vc_configs = [1, 8, 16, 32, 64, 96, 128, 160] # Provide vc configurations used
reps = [1, 2, 3]
middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log", "client_02_0.log", "client_02_1.log"]
warmup_period_endtime = 10
cooldown_period_starttime = 72
ping_logfile = "client_ping_01.log"
outdir = "./graphs"
experiment_label = "exp3_2_2"
xlim=30
num_threads=4

fig, axes = plt.subplots(1,4, sharey=True, figsize=(15, 4))
resptime.graph_responsetime(8, 96, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[0])
resptime.graph_responsetime(16, 96, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[1])

resptime.graph_responsetime(32, 96, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[2])
resptime.graph_responsetime(64, 96, num_threads, "writeOnly", middlewares, client_logfiles, reps, inputdir, xlim, axes[3])
fig.tight_layout()
plt.show()

fig.savefig(os.path.join(outdir, experiment_label, "responseTimeBreakDown_writeOnly.png"), dpi=300)

# %%
inputdir = exp3_2_rerun
worker_configs = [8, 16, 32, 64] # Provide worker configurations used
vc_configs = [1, 8, 16, 32, 64, 96, 128, 160] # Provide vc configurations used
reps = [1, 2, 3]
middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log", "client_02_0.log", "client_02_1.log"]
warmup_period_endtime = 10
cooldown_period_starttime = 72
ping_logfile = "client_ping_01.log"
outdir = "./graphs"
experiment_label = "exp3_2_2"
ylim=125
num_threads=4

fig, axes = plt.subplots(1,4, sharey=True, figsize=(11, 4))
queuelen.graph_queuelength([8,16,32,64], 8, 4, "writeOnly", ["middleware_04", "middleware_05"], [1,2,3], "/home/flo/Documents/eth-asl-final-experiment-data/exp3/3_2_rerun_twomt_2017-11-27_213817", ylim,axes[0])
queuelen.graph_queuelength([8,16,32,64], 16, 4, "writeOnly", ["middleware_04", "middleware_05"], [1,2,3], "/home/flo/Documents/eth-asl-final-experiment-data/exp3/3_2_rerun_twomt_2017-11-27_213817", ylim,axes[1])
queuelen.graph_queuelength([8,16,32,64], 32, 4, "writeOnly", ["middleware_04", "middleware_05"], [1,2,3], "/home/flo/Documents/eth-asl-final-experiment-data/exp3/3_2_rerun_twomt_2017-11-27_213817", ylim,axes[2])
queuelen.graph_queuelength([8,16,32,64], 64, 4, "writeOnly", ["middleware_04", "middleware_05"], [1,2,3], "/home/flo/Documents/eth-asl-final-experiment-data/exp3/3_2_rerun_twomt_2017-11-27_213817", ylim,axes[3])
fig.tight_layout()
plt.show()

fig.savefig(os.path.join(outdir, experiment_label, "averageQueueLength_writeOnly.png"), dpi=300)

# %%
### Drawing an experiment trace
# Throughput from the Middleware and Memtier, as well as the responsetime from both machines

inputdir = exp3_2_inputdir
worker_configuration = [8,16,32,64]
folder_prefix = "writeOnly_32vc"
middlewares = ["middleware_04", "middleware_05"]
client_logfiles = ["client_01_0.log", "client_01_1.log"]
reps = [1,2,3]
outdir = "./graphs/exp3_2"

f, axes = plt.subplots(2, 2, sharex=True)
xput_vs_time.plot_mw_metric_over_time(inputdir, worker_configuration, "throughput_mw", folder_prefix, reps, middlewares, axes[0,0])
xput_vs_time.plot_mt_metric_over_time(inputdir, worker_configuration, "throughput", folder_prefix, reps, client_logfiles, axes[1,0])
xput_vs_time.plot_mw_metric_over_time(inputdir, worker_configuration, "responseTime_ms", folder_prefix, reps, middlewares, axes[0,1])
xput_vs_time.plot_mt_metric_over_time(inputdir, worker_configuration, "responsetime", folder_prefix, reps, client_logfiles, axes[1,1])
plt.show()
f.savefig(os.path.join(outdir, '{}_experiment_trace.png'.format(folder_prefix)),dpi=600)
